# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dff=pd.read_csv("Placement_Data_Full_Class.csv")
dff
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dff.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %% [markdown]
# ## Filling value as 0 of null values in salary

# %%
dff['salary'].fillna(value=0, inplace=True)

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          215 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %% [markdown]
# ## EDA Questions

# %% [markdown]
# ### Ques1. To get placed with highest salary which degree should be Opted?

# %%
dff.degree_t.value_counts()
# Out:
# Comm&Mgmt    145
# Sci&Tech      59
# Others        11
# Name: degree_t, dtype: int64

# %%
dfST=np.array(dff[(dff.degree_t=='Sci&Tech')].salary)
dfCM=np.array(dff[(dff.degree_t=='Comm&Mgmt')].salary)
dfO=np.array(dff[(dff.degree_t=='Others')].salary)


_=plt.hist(dfST,bins=25,histtype='step')
_=plt.hist(dfCM,bins=25,histtype='step')
_=plt.hist(dfO,bins=25,histtype='step')

plt.xlabel('Salary')
plt.ylabel('Number of students')

_ = plt.legend(('Sci&Tech', 'Comm&Mgmt', 'Others'))
plt.show()

# %% [markdown]
# #### As we can see the degree "Comm&Mgmt" has the hightest salary.So, "Comm&Mgmt" should be opted for highest salary!!

# %% [markdown]
# ### Ques2. Which specialisation has the highest "mba_p" ?

# %%
dff.specialisation.value_counts()
# Out:
# Mkt&Fin    120
# Mkt&HR      95
# Name: specialisation, dtype: int64

# %%
dfMF=np.array(dff[(dff.specialisation=='Mkt&Fin')].mba_p)
dfMH=np.array(dff[(dff.specialisation=='Mkt&HR')].mba_p)

# %%
_=plt.hist(dfMF,bins=20,histtype='step')
_=plt.hist(dfMH,bins=20,histtype='step')
_=plt.legend(('Mkt&Fin', 'Mkt&HR'))
plt.xlabel('MBA_P')
plt.ylabel('Number of students')
plt.show()

# %% [markdown]
# #### As we can see the "mba_p" of "Mkt&Fin" specialsation is the most.So,student with "Mkt&Fin" specialsation has the highest "mba_p"!!

# %% [markdown]
# ## Label Encoding the columns

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
dff['status']=le.fit_transform(dff['status'])
dff['hsc_b']=le.fit_transform(dff['hsc_b'])
dff['workex']=le.fit_transform(dff['workex'])
dff['gender']=le.fit_transform(dff['gender'])
dff['ssc_b']=le.fit_transform(dff['ssc_b'])
dff['hsc_s']=le.fit_transform(dff['hsc_s'])
dff['degree_t']=le.fit_transform(dff['degree_t'])
dff['specialisation']=le.fit_transform(dff['specialisation'])

# %% [markdown]
# ## Checking correlation (Feature Selection)

# %%
import seaborn as sb
plt.rcParams['figure.figsize'] = 12,10


sb.heatmap(dff.corr(),annot=True)

# %%
dff.drop(['sl_no','ssc_b','degree_t','mba_p','ssc_p','hsc_p','salary'], axis = 1,inplace=True)

# %%
sb.heatmap(dff[['gender', 'hsc_b', 'hsc_s', 'degree_p', 'workex', 'etest_p',
       'specialisation']].corr(),annot=True)

# %%
dff.columns
# Out:
# Index(['gender', 'hsc_b', 'hsc_s', 'degree_p', 'workex', 'etest_p',
#        'specialisation', 'status'],
#       dtype='object')

# %% [markdown]
# ## Assigning Independent and Dependent Variables

# %%
X = dff[['gender', 'hsc_b', 'hsc_s', 'degree_p', 'workex', 'etest_p',
       'specialisation']]
y = dff[['status']]

# %% [markdown]
# ## Train & Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=0)

# %% [markdown]
# ### 1. SVM

# %%
from sklearn.svm import SVC
svc=SVC()

# %%
svc.fit(X_train,y_train)
# Out:
# C:\Users\Lovish Saluja\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# SVC()

# %%
y_pred1 = svc.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred1, y_test)
# Out:
# 0.6851851851851852

# %% [markdown]
# ### 2. Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()

# %%
logreg.fit(X_train, y_train)
y_pred2 = logreg.predict(X_test)
# Out:
# C:\Users\Lovish Saluja\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
logreg.score(X_test, y_test)
# Out:
# 0.7777777777777778

# %% [markdown]
# ### 3. KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
KN=KNeighborsClassifier()

# %%
KN.fit(X_train,y_train)
# Out:
# <ipython-input-28-e258bd0a7847>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   KN.fit(X_train,y_train)
# KNeighborsClassifier()

# %%
y_pred3=KN.predict(X_test)

# %%
accuracy_score(y_test,y_pred3)
# Out:
# 0.7592592592592593

# %% [markdown]
# ## Comparing Accuracies of 3 models

# %% [markdown]
# We see the best model is **Logistic Regression** with **77.77%** accuracy, followed by **KNN Classification** with **75.92%** accuracy and **Support Vector Machine (SVM)** with **68.51%** accuracy.
